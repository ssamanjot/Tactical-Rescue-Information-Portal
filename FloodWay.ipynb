# %%
# %env GBDX_USERNAME = prabhjotsingh@cmu.edu
# %env GBDX_PASSWORD = N@vdeep353
# Out:
# env: GBDX_USERNAME=prabhjotsingh@cmu.edu
# env: GBDX_PASSWORD=N@vdeep353

# %%
# notebook setup
from gbdxtools.task import env
from gbdxtools import CatalogImage
from gbdxtools import Interface
               
import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib inline

gbdx = Interface()

              

                
# search for modis imagery during the event
wkt_string='POLYGON ((76.629638671875 5.922044619883305, 80.17822265625 5.922044619883305, 80.17822265625 9.167178732976677, 76.629638671875 9.167178732976677, 76.629638671875 5.922044619883305))'
bbox = '76.629638671875, 5.922044619883305, 80.17822265625, 9.167178732976677'
   
query = gbdx.catalog.search(searchAreaWkt=wkt_string,
                            startDate = '2017-05-20T00:00:00.000Z',
                            endDate = '2017-06-01T00:00:00.000Z',
                            types = ['MODISProduct']
                           )
for item in query:
    print('ID: ' + item['identifier'], 'DATE: ' + item['properties']['timestamp'])
# Out:
# C:\Users\a\Anaconda3\lib\site-packages\gbdxtools\images\meta.py:21: UserWarning: ShareDict has been deprecated in favor of HighLevelGraph and will be removed in future versions
#   from dask import sharedict, optimization
# (u'ID: MOD09GA.A2017148.h25v08.006.2017150030232', u'DATE: 2017-05-28T00:00:00.000Z')
# (u'ID: MOD09GA.A2017142.h25v08.006.2017144025337', u'DATE: 2017-05-22T00:00:00.000Z')
# (u'ID: MOD09GA.A2017145.h25v08.006.2017151143109', u'DATE: 2017-05-25T00:00:00.000Z')
# (u'ID: MOD09GA.A2017141.h25v08.006.2017143031114', u'DATE: 2017-05-21T00:00:00.000Z')
# (u'ID: MOD09GA.A2017144.h25v08.006.2017146030749', u'DATE: 2017-05-24T00:00:00.000Z')
# (u'ID: MOD09GA.A2017140.h25v08.006.2017142024042', u'DATE: 2017-05-20T00:00:00.000Z')
# (u'ID: MOD09GA.A2017143.h25v08.006.2017145030845', u'DATE: 2017-05-23T00:00:00.000Z')
# (u'ID: MOD09GA.A2017146.h25v08.006.2017148030218', u'DATE: 2017-05-26T00:00:00.000Z')
# ...

# %%
              

                
# retrieve images
image_may20 = CatalogImage('MOD09GA.A2017140.h25v08.006.2017142024042', bbox=map(float, bbox.split(',')))
image_may22 = CatalogImage('MOD09GA.A2017142.h25v08.006.2017144025337', bbox=map(float, bbox.split(',')))

# %%
#no pan sharpening or Acomp
ald_image = CatalogImage('MOD09GA.A2017140.h25v08.006.2017142024042', band_type="MS", bbox=map(float, bbox.split(",")))
ald_image.plot()

#Tell us the data type in the arrays
ald_image.dtype
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-fe3cf857245d> in <module>()
#       1 #no pan sharpening or Acomp
#       2 ald_image = CatalogImage('MOD09GA.A2017140.h25v08.006.2017142024042', band_type="MS", bbox=map(float, bbox.split(",")))
# ----> 3 ald_image.plot()
#       4
#       5 #Tell us the data type in the arrays
#
# C:\Users\a\Anaconda3\lib\site-packages\gbdxtools\images\mixins\geo.pyc in plot(self, spec, **kwargs)
#     193                 self._plot(tfm=self.rgb, **kwargs)
#     194             else:
# --> 195                 self._plot(tfm=getattr(self, spec), **kwargs)
#     196
#     197     def _has_token(self, **kwargs):
#
# C:\Users\a\Anaconda3\lib\site-packages\gbdxtools\images\mixins\geo.pyc in _plot(self, tfm, **kwargs)
#     208         ax1.axis('off')
# ...

# %%
from gbdxtools.task import env
from gbdxtools import CatalogImage
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

bbox = env.inputs.get('bbox', '81.72399044036867, 25.432462031411447, 81.74270153045656, 25.44765362516609')

catalog_id1 = env.inputs.get('catalog_id1', '2003121605224350000011600058')
image_id1 = CatalogImage(catalog_id1, bbox=map(float, bbox.split(",")))

#no pan sharpening or Acomp
ald_image = CatalogImage(catalog_id1, band_type="MS", bbox=map(float, bbox.split(",")))
ald_image.plot()

#Tell us the data type in the arrays
ald_image.dtype
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-13-6d1475cbca9a> in <module>()
#      12 #no pan sharpening or Acomp
#      13 ald_image = CatalogImage(catalog_id1, band_type="MS", bbox=map(float, bbox.split(",")))
# ---> 14 ald_image.plot()
#      15
#      16 #Tell us the data type in the arrays
#
# C:\Users\a\Anaconda3\lib\site-packages\gbdxtools\images\mixins\geo.pyc in plot(self, spec, **kwargs)
#     193                 self._plot(tfm=self.rgb, **kwargs)
#     194             else:
# --> 195                 self._plot(tfm=getattr(self, spec), **kwargs)
#     196
#     197     def _has_token(self, **kwargs):
#
# C:\Users\a\Anaconda3\lib\site-packages\gbdxtools\images\mixins\geo.pyc in _plot(self, tfm, **kwargs)
#     208         ax1.axis('off')
#     209         ax1.set_title(kwargs.get('title', ''), fontsize=kwargs.get('fontsize', 22))
# ...
